# %% [markdown]
# # 서울에서 김서방 찾기

# %%
def solution(seoul):
    num = 0
    for i, first in enumerate(seoul):
        if first == 'Kim':
            num = i
            break
    answer = '김서방은 '+str(num)+'에 있다'
    return answer

# %% [markdown]
# # 124나라
